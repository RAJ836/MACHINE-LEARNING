# %%
doubts :
    questions : 15

# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv(r'C:\Users\91955\Documents\MY_OWN_ML\PANDAS\pandas_exercises\IMDB_EXERCISE\imdb.csv')

# %% [markdown]
# **1. Write a Python Pandas program to get the columns of the DataFrame**

# %%
#movies=pd.read_csv(r'C:\Users\91955\Documents\MY_OWN_ML\PANDAS\pandas_exercises\IMDB_EXERCISE\movies_metadata.csv')
#movies

# %%
movies=pd.read_csv(r'C:\Users\91955\Documents\MY_OWN_ML\PANDAS\pandas_exercises\IMDB_EXERCISE\imdb.csv')
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# **2. Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file)including data types and memory usage**

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
# adult                    50 non-null bool
# belongs_to_collection    10 non-null object
# budget                   50 non-null int64
# genres                   50 non-null object
# homepage                 5 non-null object
# id                       50 non-null int64
# imdb_id                  50 non-null object
# original_language        50 non-null object
# original_title           50 non-null object
# overview                 49 non-null object
# popularity               50 non-null float64
# poster_path              50 non-null object
# production_companies     50 non-null object
# production_countries     50 non-null object
# release_date             50 non-null object
# revenue                  50 non-null int64
# runtime                  50 non-null float64
# spoken_languages         50 non-null object
# status                   50 non-null object
# ...

# %% [markdown]
# **3. Write a Pandas program to get the details of the third movie of the DataFrame**

# %%
movies.iloc[2]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# **4. Write a Pandas program to count the number of rows and columns of the DataFrame**

# %%
print("rows and columns : ")
movies.shape
# Out:
# rows and columns :
# (50, 24)

# %% [markdown]
# **5. Write a Pandas program to get the details of the columns title and genres of the DataFrame.**

# %%
movies[['title','genres']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# 5                             Heat
# 6                          Sabrina
# 7                     Tom and Huck
# 8                     Sudden Death
# 9                        GoldenEye
# 10          The American President
# 11     Dracula: Dead and Loving It
# 12                           Balto
# 13                           Nixon
# 14                Cutthroat Island
# 15                          Casino
# 16           Sense and Sensibility
# 17                      Four Rooms
# 18  Ace Ventura: When Nature Calls
# 19                     Money Train
# 20                      Get Shorty
# 21                         Copycat
# 22                       Assassins
# 23                          Powder
# 24               Leaving Las Vegas
# ...

# %% [markdown]
# **6. Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'.**

# %%
movies[movies['title']=='Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ...  release_date  \
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
#
#   revenue runtime                          spoken_languages    status  \
# 2       0   101.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 2          6.5         92
#
# [1 rows x 24 columns]

# %% [markdown]
# **7. Write a Pandas program to get the details of  fifth movie of the DataFrame.**

# %%
movies.iloc[4]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                         8.38752
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %% [markdown]
# **8. Write a Pandas program to create a smaller DataFrame with a subset of all features**

# %%
df=movies[['title','budget','revenue','release_date']]
df.head()
# Out:
#                          title    budget    revenue release_date
# 0                    Toy Story  30000000  373554033   1995-10-30
# 1                      Jumanji  65000000  262797249   1995-12-15
# 2             Grumpier Old Men         0          0   1995-12-22
# 3            Waiting to Exhale  16000000   81452156   1995-12-22
# 4  Father of the Bride Part II         0   76578911   1995-02-10

# %% [markdown]
# **9. Write a Pandas program to display the first 10 rows of the DataFrame**

# %%
movies.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %% [markdown]
# **10. Write a Pandas program to sort the DataFrame based on release_date.**

# %%
movies.sort_values(by='release_date').head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 29  False                                                NaN         0
# 48  False                                                NaN         0
# 28  False                                                NaN  18000000
# 44  False                                                NaN  20000000
#
#                                                genres homepage     id  \
# 4                      [{'id': 35, 'name': 'Comedy'}]      NaN  11862
# 29  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN  37557
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   8391
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 44  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN    577
#
#       imdb_id original_language               original_title  \
# ...

# %% [markdown]
# **11. Write a Pandas program to access those movies, released after 1995-01-01**

# %%
# converting to datetime 
movies['release_date']=pd.to_datetime(movies['release_date']) 
movies[['title','budget','revenue','release_date']][movies['release_date']>'1995-01-01'].sort_values('release_date')
# Out:
#                              title    budget    revenue release_date
# 4      Father of the Bride Part II         0   76578911   1995-02-10
# 29                  Shanghai Triad         0          0   1995-04-30
# 48           When Night Is Falling         0          0   1995-05-05
# 28       The City of Lost Children  18000000    1738611   1995-05-16
# 44                      To Die For  20000000   21284514   1995-05-20
# 47                      Pocahontas  55000000  346079773   1995-06-14
# 33                            Babe  30000000  254134910   1995-07-18
# 38                        Clueless  12000000          0   1995-07-19
# 49              The Usual Suspects   6000000   23341568   1995-07-19
# 30                 Dangerous Minds         0  180000000   1995-08-11
# 43                   Mortal Kombat  18000000  122195920   1995-08-18
# 46                           Se7en  33000000  327311859   1995-09-22
# 27                      Persuasion         0          0   1995-09-27
# ...

# %% [markdown]
# **12. Write a Pandas program to sort movies on runtime in descending order**

# %%
cols=['title','budget','revenue','release_date','runtime']
movies[cols].sort_values(by='runtime',ascending=False).head()
# Out:
#                     title    budget    revenue release_date  runtime
# 13                  Nixon  44000000   13681765   1995-12-22    192.0
# 15                 Casino  52000000  116112375   1995-11-22    178.0
# 5                    Heat  60000000  187436818   1995-12-15    170.0
# 16  Sense and Sensibility  16500000  135000000   1995-12-13    136.0
# 22              Assassins  50000000   30303072   1995-10-06    132.0

# %% [markdown]
# **13. Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million.**

# %%
cond1=movies['budget']<1000000
cond2=movies['revenue']>2000000
movies[cols][cond1 & cond2]
# Out:
#                           title  budget    revenue release_date  runtime
# 4   Father of the Bride Part II       0   76578911   1995-02-10    106.0
# 12                        Balto       0   11348324   1995-12-22     78.0
# 30              Dangerous Minds       0  180000000   1995-08-11     99.0

# %% [markdown]
# **14. Write a Pandas program to get the longest runtime and shortest runtime.**

# %%
print("Longest and shortest runtime movies :")
movies[cols].iloc[[movies['runtime'].idxmax()]+[movies['runtime'].idxmin()]]
# Out:
# Longest and shortest runtime movies :
#                title    budget   revenue release_date  runtime
# 13             Nixon  44000000  13681765   1995-12-22    192.0
# 32  Wings of Courage         0         0   1996-09-18     50.0

# %% [markdown]
# **15. Write a Pandas program to calculate the number of votes garnered by the 70% movie**

# %%
#movies['vote_count'].quantile(0.70)

# %% [markdown]
# **16. Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 100 minutes.**

# %%
boo=movies['runtime'].between(30,100,inclusive=False)
movies[cols][boo].sort_values('runtime')
# Out:
#                              title    budget    revenue release_date  runtime
# 32                Wings of Courage         0          0   1996-09-18     50.0
# 36          Across the Sea of Time         0          0   1995-10-20     51.0
# 12                           Balto         0   11348324   1995-12-22     78.0
# 0                        Toy Story  30000000  373554033   1995-10-30     81.0
# 47                      Pocahontas  55000000  346079773   1995-06-14     81.0
# 11     Dracula: Dead and Loving It         0          0   1995-12-22     88.0
# 33                            Babe  30000000  254134910   1995-07-18     89.0
# 18  Ace Ventura: When Nature Calls  30000000  212385533   1995-11-10     90.0
# 48           When Night Is Falling         0          0   1995-05-05     96.0
# 7                     Tom and Huck         0          0   1995-12-22     97.0
# 38                        Clueless  12000000          0   1995-07-19     97.0
# ...
